# %%
# This block allows us to import from the benchmark folder,
# as if it was a package installed using pip
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from attrbench import datasets, attribution, models
from attrbench.evaluation.deletion_curves import deletion_curves
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from os import path
import matplotlib as mpl
import torch
mpl.rcParams['figure.dpi'] = 150

# %%
# General parameters
dataset_name = "MNIST"
batch_size = 64
n_batches = 16
use_logits = False
data_root = "../data"
aggregation_fn = "avg"
normalize_attrs = True
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
# CIFAR10 parameters
if dataset_name == "CIFAR10":
    model_name = "resnet18"
    mask_range = list(range(1, 900, 100))
    dataset = datasets.Cifar(batch_size=batch_size, data_location=path.join(data_root, "CIFAR10"), download=False, shuffle=False, version="cifar10")
    model = model = models.Resnet(version=model_name, params_loc=path.join(data_root, f"models/{dataset_name}/{model_name}.pt"),
                      output_logits=use_logits, num_classes=10)
    model.to(device)
    model.eval()

# %%
# MNIST parameters
if dataset_name == "MNIST":
    mask_range = list(range(1, 128, 10))
    dataset = datasets.MNIST(batch_size=batch_size, data_location=path.join(data_root, "MNIST"), download=False, shuffle=False)
    model = models.BasicCNN(params_loc=path.join(data_root, "models/MNIST/cnn.pt"), output_logits=use_logits, num_classes =10)
    model.to(device)
    model.eval()

# %%
kwargs = {
    "normalize": normalize_attrs,
    "aggregation_fn": aggregation_fn
}

attribution_methods = {
    #"GuidedGradCAM": attribution.GuidedGradCAM(model, model.get_last_conv_layer(), **kwargs),
    "Gradient": attribution.Gradient(model, **kwargs),
    "InputXGradient": attribution.InputXGradient(model, **kwargs),
    "IntegratedGradients": attribution.IntegratedGradients(model, **kwargs),
    "GuidedBackprop": attribution.GuidedBackprop(model, **kwargs),
    "Deconvolution": attribution.Deconvolution(model, **kwargs),
}

# %%
result = deletion_curves(itertools.islice(dataset.get_dataloader(train=False), n_batches), model,
                         attribution_methods, mask_range, dataset.mask_value, pixel_level_mask=aggregation_fn is not None,
                         device=device)
# Out:
# warning: PYDEVD_USE_CYTHON environment variable is set to 'NO'. Frame evaluator will be also disabled because it requires Cython extensions to be enabled in order to operate correctly.
# 0it [00:00, ?it/s]/home/arne/Documents/PhD/projects/benchmark/venv/lib/python3.7/site-packages/captum/attr/_utils/gradient.py:33: UserWarning: Input Tensor 0 did not already require gradients, required_grads has been set automatically.
#   "required_grads has been set automatically." % index
# 0it [00:39, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6253ab5f938c> in <module>
#       2 result = deletion_curves(itertools.islice(dataset.get_dataloader(train=False), n_batches), model,
#       3                          attribution_methods, mask_range, dataset.mask_value, pixel_level_mask=aggregation_fn is not None,
# ----> 4                          device=device)
#       5
#
# ~/Documents/PhD/projects/benchmark/attrbench/evaluation/deletion_curves/deletion_curves.py in deletion_curves(data, model, methods, mask_range, mask_value, pixel_level_mask, device)
#      25                 if pixel_level_mask:
#      26                     unraveled = np.unravel_index(to_mask, samples.shape[2:])
# ---> 27                     masked_samples[(batch_dim, -1, *unraveled)] = mask_value
#      28                 else:
#      29                     unraveled = np.unravel_index(to_mask, samples.shape[1:])
#
# ~/Documents/PhD/projects/benchmark/attrbench/evaluation/deletion_curves/deletion_curves.py in deletion_curves(data, model, methods, mask_range, mask_value, pixel_level_mask, device)
#      25                 if pixel_level_mask:
#      26                     unraveled = np.unravel_index(to_mask, samples.shape[2:])
# ---> 27                     masked_samples[(batch_dim, -1, *unraveled)] = mask_value
#      28                 else:
#      29                     unraveled = np.unravel_index(to_mask, samples.shape[1:])
#
# /snap/pycharm-professional/201/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py in trace_dispatch(self, frame, event, arg)
#     719                 # if thread has a suspend flag, we suspend with a busy wait
#     720                 if info.pydev_state == STATE_SUSPEND:
# --> 721                     self.do_wait_suspend(thread, frame, event, arg)
#     722                     # No need to reset frame.f_trace to keep the same trace function.
#     723                     return self.trace_dispatch
#
# /snap/pycharm-professional/201/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py in do_wait_suspend(self, *args, **kwargs)
#     142
#     143     def do_wait_suspend(self, *args, **kwargs):
# --> 144         self._args[0].do_wait_suspend(*args, **kwargs)
#     145
#     146     # IFDEF CYTHON
#
# /snap/pycharm-professional/201/plugins/python/helpers/pydev/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1101
#    1102         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1103             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1104
#    1105     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# /snap/pycharm-professional/201/plugins/python/helpers/pydev/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1116
#    1117                 self.process_internal_commands()
# -> 1118                 time.sleep(0.01)
#    1119
#    1120         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
result_df = pd.DataFrame.from_dict(
    {m_name: pd.DataFrame(data=result[m_name]).stack() for m_name in attribution_methods}
).stack().reset_index()
result_df.columns = ["sample", "mask", "method", "difference"]
result_df["mask"] = np.array(mask_range)[result_df["mask"]]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x="mask", y="difference", hue="method", data=result_df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
