# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
def lineplot(exp_name, x, y):
    filenames = [f"../out/{exp_name}.pkl" for i in range(2)]
    dfs = [pd.read_pickle(f) for f in filenames]
    df = pd.concat(dfs)
    plt.figure(figsize=(10, 5))
    sns.lineplot(x=x, y=y, hue="method", data=df, ci=99)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
def boxplot(exp_name, x, y, xtick_rotation):
    filenames = [f"../out/{exp_name}.pkl" for i in range(2)]
    dfs = [pd.read_pickle(f) for f in filenames]
    df = pd.concat(dfs)
    plt.figure(figsize=(10, 5))
    ax = sns.boxplot(x=x, y=y, data=df, showfliers=False)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=xtick_rotation)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
lineplot("deletion_curves_mnist", "mask", "difference")

# %%
lineplot("insertion_curves_mnist", "insertion", "difference")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-62fb5659578c> in <module>
# ----> 1 lineplot("insertion_curves_mnist", "insertion", "difference")
#
# <ipython-input-2-2b820b4cd10b> in lineplot(exp_name, x, y)
#       4     df = pd.concat(dfs)
#       5     plt.figure(figsize=(10, 5))
# ----> 6     sns.lineplot(x=x, y=y, hue="method", data=df, ci=99)
#       7     plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#
# ~/Documents/PhD/projects/benchmark/venv/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1135         ax = plt.gca()
#    1136
# -> 1137     p.plot(ax, kwargs)
#    1138     return ax
#    1139
#
# ...

# %%
boxplot("infidelity_mnist", "method", "infidelity", xtick_rotation=30)

# %%
lineplot("sensitivity_n_mnist", "n", "correlation")

# %%
lineplot("max_sensitivity_mnist", "r", "max_sens")
