# %%
import torch
import numpy as np
from torch.utils.data import DataLoader

from attrbench.evaluation.independent import max_sensitivity
from experiments.lib.util import get_ds_model, get_mask_range, get_methods
from experiments.test.util import imshow, attrshow, show_img_attrs

# %% [markdown]
# # Initialization and parameters

# %%
BATCH_SIZE = 4
DATASET = "MNIST"
MODEL = "CNN"
METHOD = "Gradient"
N_PERTURBATIONS = 16

device = "cuda" if torch.cuda.is_available() else "cpu"
dataset, model = get_ds_model(DATASET, MODEL)
methods = get_methods(model, aggregation_fn="avg", normalize=True, methods=[METHOD],
                      batch_size=BATCH_SIZE, sample_shape=dataset.sample_shape[-2:])
method = methods[METHOD]
model.to(device)
for param in model.parameters():
    param.requires_grad = False
model.eval()
pert_range = list(np.linspace(.01, 2., 20))

# %% [markdown]
# # Run Max-Sensitivity

# %%
batch, labels = next(iter(DataLoader(dataset, BATCH_SIZE, num_workers=4)))
batch = batch.to(device)
labels = labels.to(device)
infid, debug_data = max_sensitivity(batch, labels, method, pert_range, N_PERTURBATIONS, debug_mode=True)
# Out:
# /home/arne/Documents/PhD/projects/benchmark/venv/lib/python3.8/site-packages/captum/attr/_utils/gradient.py:31: UserWarning: Input Tensor 0 did not already require gradients, required_grads has been set automatically.
#   warnings.warn(

# %% [markdown]
# # Plot results

# %% [markdown]
# ## Plot the original samples and their attributions

# %%
show_img_attrs(dataset.denormalize(batch), debug_data["attrs"])

# %% [markdown]
# ## Plot perturbed samples and values for each perturbation step

# %%
for eps_idx, eps_data in enumerate(debug_data["pert_data"]):
    print(f"eps: {pert_range[eps_idx]}")
    for pert_idx in range(2):
        perturbation = eps_data["perturbations"][pert_idx]
        imshow(perturbation, title="Perturbations")
        perturbed_samples = eps_data["perturbed_samples"][pert_idx]
        imshow(dataset.denormalize(perturbed_samples), title="Perturbed samples")
    print()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# eps: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# eps: 0.11473684210526315
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
